# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya-m-11/bookish-guide/blob/develop/s_BOOK_SAMPLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
api_key = "AIzaSyC58XPlPym-sSinBMGfmaA1MCDjFnlkTeQ"

# %%
def scrap(query,api_key):
  url = "https://www.googleapis.com/books/v1/volumes"
  params = {"q": query,
          "key": api_key,
          "maxResults":40}
  response = requests.get(url, params=params)
  return  response

# %%
scrap(api_key,'python')
# Out:
# <Response [400]>

# %%
def extract_data(data):
  return data

# %%
data = scrap('python',api_key)
d = data.json()

# %%
d
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 1533,
#  'items': [{'kind': 'books#volume',
#    'id': 'DjxZEAAAQBAJ',
#    'etag': 'qrc3y5F/KJc',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/DjxZEAAAQBAJ',
#    'volumeInfo': {'title': 'The Python Book',
#     'authors': ['Rob Mastrodomenico'],
#     'publisher': 'John Wiley & Sons',
#     'publishedDate': '2022-01-13',
# ...

# %%
len
# Out:
# <function len(obj, /)>

# %%
d
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 1533,
#  'items': [{'kind': 'books#volume',
#    'id': 'DjxZEAAAQBAJ',
#    'etag': 'qrc3y5F/KJc',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/DjxZEAAAQBAJ',
#    'volumeInfo': {'title': 'The Python Book',
#     'authors': ['Rob Mastrodomenico'],
#     'publisher': 'John Wiley & Sons',
#     'publishedDate': '2022-01-13',
# ...

# %%
d.keys()
# Out:
# dict_keys(['kind', 'totalItems', 'items'])

# %%
len(d['items'])
# Out:
# 40

# %%
d['items'][0]['id']
# Out:
# 'DjxZEAAAQBAJ'

# %%
for i in d['items']:
  print(i['id'])
# Out:
# DjxZEAAAQBAJ
# nEJ-jcYF2fMC
# 69IyAgAAQBAJ
# bIZHCgAAQBAJ
# C3ymDwAAQBAJ
# KZvM0AEACAAJ
# igYvDwAAQBAJ
# XAIHEAAAQBAJ
# 7GUKEAAAQBAJ
# __wvEQAAQBAJ
# w1v6DwAAQBAJ
# HFeGvgEACAAJ
# aJQILlLxRmAC
# 10KYwCZxSdEC
# J5Y2EAAAQBAJ
# S_SJ2LaZH8EC
# ePyeNz2Eoy8C
# 9dW8DwAAQBAJ
# ZB9sDwAAQBAJ
# ygzJEAAAQBAJ
# 6omNDQAAQBAJ
# EVuk7eqhWiwC
# 7MmeyhTnqRkC
# J9b_CH-NrycC
# KTgzEAAAQBAJ
# Wd_PJ2y68uIC
# iIpGEAAAQBAJ
# d_f1DwAAQBAJ
# P5DUDwAAQBAJ
# KGIbfiiP1i4C
# h-_sBQAAQBAJ
# f4g9zgEACAAJ
# _J5lEAAAQBAJ
# ZPneDQAAQBAJ
# zjqzDAEACAAJ
# bi59DwAAQBAJ
# fKZwzgEACAAJ
# Kn8nCgAAQBAJ
# VxDGDwAAQBAJ
# JnR9hQA3SncC

# %%
data = {'t' : d['items'][0]['volumeInfo']['title'],
's_t' : d['items'][0]['volumeInfo'].get('subtitle','NA'),
'id' : d['items'][0]['id']}

# %%
data = {'t' : d['items'][4]['volumeInfo']['title'],
's_t' : d['items'][4]['volumeInfo'].get('subtitle','NA'),
'id' : d['items'][4]['id']}

# %%
data
# Out:
# {'t': 'Python Crash Course',
#  's_t': 'A Hands-On, Project-Based Introduction to Programming',
#  'id': 'igYvDwAAQBAJ'}

# %%
all_data=[]
for i in d['items']:
    data = {'t' : i['volumeInfo']['title'],
    's_t' : i['volumeInfo'].get('subtitle','NA'),
    'id' : i['id']}
    all_data.append(data)

# %%
all_data=[]
for i in d['items']:
    data = {'detail':i['volumeInfo']}
    all_data.append(data)

# %%
all_data
# Out:
# [{'detail': {'title': 'The Python Book',
#    'authors': ['Rob Mastrodomenico'],
#    'publisher': 'John Wiley & Sons',
#    'publishedDate': '2022-01-13',
# ...

# %%
d
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 1952,
#  'items': [{'kind': 'books#volume',
#    'id': 'DjxZEAAAQBAJ',
#    'etag': '8jm/ROVD/lg',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/DjxZEAAAQBAJ',
#    'volumeInfo': {'title': 'The Python Book',
#     'authors': ['Rob Mastrodomenico'],
#     'publisher': 'John Wiley & Sons',
#     'publishedDate': '2022-01-13',
# ...
